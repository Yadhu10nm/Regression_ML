# %%
import pathlib
print("Notebook path:", pathlib.Path().resolve())
# Out:
# Notebook path: C:\MACHINE_LEARNING\Regression\Projects

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("data/student_performance.csv")
df.head()
# Out:
#    study_hours  attendance  sleep_hours  social_media  assignments  \
# 0          2.6        82.1          4.5           1.0            6
# 1          5.7        54.2          8.5           1.7            1
# 2          4.5        58.1          6.5           1.1            0
# 3          3.8        94.9          8.1           0.5            3
# 4          1.4        80.3          5.6           0.7            6
#
#    final_score
# 0         90.1
# 1         84.4
# 2         70.3
# 3         97.4
# 4         78.8

# %%
df.shape
# Out:
# (200, 6)

# %%
data = df.to_numpy()
data
# Out:
# array([[  2.6,  82.1,   4.5,   1. ,   6. ,  90.1],
#        [  5.7,  54.2,   8.5,   1.7,   1. ,  84.4],
#        [  4.5,  58.1,   6.5,   1.1,   0. ,  70.3],
#        ...,
#        [  5.4,  71.4,   4.9,   3.4,   3. ,  87.4],
#        [  5.4,  87.5,   5. ,   4.2,   4. , 100. ],
#        [  4.8,  87.7,   4.2,   5.5,   4. ,  94.5]])

# %%
x = data[:,0:5]
y = data[:,5].reshape(-1,1)
print(x.shape)
print(y.shape)
# Out:
# (200, 5)
# (200, 1)

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)
print(x_train.shape , x_test.shape , y_train.shape , y_test.shape )
# Out:
# (160, 5) (40, 5) (160, 1) (40, 1)

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_pred , y_test)
mse
# Out:
# 28.848758114934917

# %%
inp = np.array([[		6.0	,100,	8,	0	,6]]).reshape(1,-1)
pred = model.predict(inp)[0][0]
pred = final_pred = np.clip(pred, 0, 100)
print("prediction : ",int(pred))
# Out:
# prediction :  100
